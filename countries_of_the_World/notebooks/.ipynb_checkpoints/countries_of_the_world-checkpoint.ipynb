# %% [markdown]
# # Countries of the World
#
# This notebook is written to look at the world data and try to find some relationship between the attributes given.
#
# ### Contents of the notebook:
#
# - **Looking at Data**
# - **Visualizing Data**
# - **Finding relationship between different Attributes**

# %%
# Install a conda package in the current Jupyter kernel
import sys
# !conda install --yes --prefix {sys.prefix} geopandas

# %%
import sys
# !conda remove seaborn
# !conda install --yes --prefix {sys.prefix} seaborn=0.9.0

# %%
import pandas as pd
import numpy as np
import geopandas
from scipy import stats

import seaborn as sns
sns.set(style="darkgrid")

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the data
world_data = pd.read_csv("../input/countries_of_the_world.csv", na_values='NaN')

# %% [markdown]
# ## Looking at the Data

# %%
# Get the information about the different attributes in the data
world_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
# Country                               227 non-null object
# Region                                227 non-null object
# Population                            227 non-null int64
# Area (sq. mi.)                        227 non-null int64
# Pop. Density (per sq. mi.)            227 non-null object
# Coastline (coast/area ratio)          227 non-null object
# Net migration                         224 non-null object
# Infant mortality (per 1000 births)    224 non-null object
# GDP ($ per capita)                    226 non-null float64
# Literacy (%)                          209 non-null object
# Phones (per 1000)                     223 non-null object
# Arable (%)                            225 non-null object
# Crops (%)                             225 non-null object
# Other (%)                             225 non-null object
# Climate                               205 non-null object
# Birthrate                             224 non-null object
# Deathrate                             223 non-null object
# Agriculture                           212 non-null object
# Industry                              211 non-null object
# Service                               212 non-null object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 35.5+ KB

# %% [markdown]
# From the information above, we see that there are a lot of attributes in the data. They are:
#
# - **Country:** This entry includes country's name approved by the US Board on Geographic Name
# - **Region:** Region in which the country lies in
# - **population:** Total Number of people in the country
# - **Area (sq. mi.):** Area of country in square miles
# - **Pop. Density (per sq. mi.):** Density of population in number of people per square mile
# - **Coastline (coast/area ratio):** This entry gives the total length of the boundary between the land area (including islands) and the sea.
# - **Net migration:** This entry includes the figure for the difference between the number of persons entering and leaving a country during the year per 1,000 persons (based on midyear population). An excess of persons entering the country is referred to as net immigration (e.g., 3.56 migrants/1,000 population); an excess of persons leaving the country as net emigration (e.g., -9.26 migrants/1,000 population). The net migration rate indicates the contribution of migration to the overall level of population change. The net migration rate does not distinguish between economic migrants, refugees, and other types of migrants nor does it distinguish between lawful migrants and undocumented migrants.
# - **Infant mortality (per 1000 births):** Number of indant deaths per 1000 births
# - **GDP ($ per capita):** the total value of goods produced and services provided in a country per person during one year
# - **Literacy (%):** Total number of literate persons in a given age group, expressed as a percentage of the total population in that age group.
# - **Phones (per 1000):** Number of phones per 1000 people
# - **Arable (%):** Percentage of land used or suitable for growing crops
# - **Crops (%):** Percentage of land that is under crop irrigation
# - **Other (%):** Percentage of land that is not arable or under crop
# - **Climate:** Brief description of typical weather regimes throughout the yea
# - **Birthrate:** the number of live births per thousand of population per year
# - **Deathrate:** the number of deaths per thousand of population per year.
# - **Agriculture:** Percentage contributed to the GDP
# - **Industry:** Percentage contributed to the GDP
# - **Service:** Percentage contributed to the GDP

# %%
# Get 5 random row entries
world_data.sample(5)
# Out:
#          Country                               Region  Population  \
# 101       Italy   WESTERN EUROPE                         58133509
# 106  Kazakhstan                  C.W. OF IND. STATES     15233244
# 33      Burundi   SUB-SAHARAN AFRICA                      8090068
# 2       Algeria   NORTHERN AFRICA                        32930091
# 68      Finland   WESTERN EUROPE                          5231372
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 101          301230                      193,0                         2,52
# 106         2717300                        5,6                         0,00
# 33            27830                      290,7                         0,00
# 2           2381740                       13,8                         0,04
# 68           338145                       15,5                         0,37
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 101          2,07                               5,94             26700.0
# 106         -3,35                              29,21              6300.0
# 33          -0,06                              69,29               600.0
# 2           -0,39                                 31              6000.0
# 68           0,95                               3,57             27400.0
#
#     Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 101         98,6             430,9      27,79      9,53     62,68     NaN
# 106         98,4             164,1       7,98      0,05     91,97       4
# 33          51,6               3,4      35,05     14,02     50,93       2
# 2           70,0              78,1       3,22      0,25     96,53       1
# 68         100,0             405,3       7,19      0,03     92,78       3
#
#     Birthrate Deathrate Agriculture Industry Service
# 101      8,72      10,4       0,021    0,291   0,688
# 106        16      9,42       0,067    0,386   0,547
# 33      42,22     13,46       0,463    0,203   0,334
# 2       17,14      4,61       0,101      0,6   0,298
# 68      10,45      9,86       0,028    0,295   0,676

# %%
# Get names of regions
world_data['Region'].unique()

# I don't know what the 'NEAR EAST' region is. It is very vague and I can't pinpoint to what it represents.
# Out:
# array(['ASIA (EX. NEAR EAST)         ',
#        'EASTERN EUROPE                     ',
#        'NORTHERN AFRICA                    ',
#        'OCEANIA                            ',
#        'WESTERN EUROPE                     ',
#        'SUB-SAHARAN AFRICA                 ', 'LATIN AMER. & CARIB    ',
#        'C.W. OF IND. STATES ', 'NEAR EAST                          ',
#        'NORTHERN AMERICA                   ',
#        'BALTICS                            '], dtype=object)

# %%
# Clean Region names (remove whitespace) and set them as index
world_data['Region'] = world_data['Region'].str.strip()
world_data['Country'] = world_data['Country'].str.strip()
world_data['Region'].unique()
world_data.set_index('Region', inplace=True)
world_data.sample(5)
# Out:
#                              Country  Population  Area (sq. mi.)  \
# Region
# OCEANIA               American Samoa       57794             199
# OCEANIA                       Tuvalu       11810              26
# ASIA (EX. NEAR EAST)     Philippines    89468677          300000
# SUB-SAHARAN AFRICA            Malawi    13013926          118480
# WESTERN EUROPE                France    60876136          547030
#
#                      Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# Region
# OCEANIA                                   290,4                        58,29
# OCEANIA                                   454,2                        92,31
# ASIA (EX. NEAR EAST)                      298,2                        12,10
# SUB-SAHARAN AFRICA                        109,8                         0,00
# WESTERN EUROPE                            111,3                         0,63
#
#                      Net migration Infant mortality (per 1000 births)  \
# Region
# OCEANIA                     -20,71                               9,27
# OCEANIA                          0                              20,03
# ASIA (EX. NEAR EAST)          -1,5                              23,51
# SUB-SAHARAN AFRICA               0                             103,32
# WESTERN EUROPE                0,66                               4,26
#
#                       GDP ($ per capita) Literacy (%) Phones (per 1000)  \
# Region
# OCEANIA                           8000.0         97,0             259,5
# OCEANIA                           1100.0          NaN              59,3
# ASIA (EX. NEAR EAST)              4600.0         92,6              38,4
# SUB-SAHARAN AFRICA                 600.0         62,7               7,9
# WESTERN EUROPE                   27600.0         99,0             586,4
#
#                      Arable (%) Crops (%) Other (%) Climate Birthrate  \
# Region
# OCEANIA                      10        15        75       2     22,46
# OCEANIA                       0         0       100       2     22,18
# ASIA (EX. NEAR EAST)      18,95     16,77     64,28       2     24,89
# SUB-SAHARAN AFRICA        23,38      1,49     75,13       2     43,13
# WESTERN EUROPE            33,53      2,07      64,4       4     11,99
#
#                      Deathrate Agriculture Industry Service
# Region
# OCEANIA                   3,27         NaN      NaN     NaN
# OCEANIA                   7,11       0,166    0,272   0,562
# ASIA (EX. NEAR EAST)      5,41       0,144    0,326    0,53
# SUB-SAHARAN AFRICA       19,33       0,342    0,158   0,499
# WESTERN EUROPE            9,14       0,022    0,214   0,764

# %%
# Replace ',' with '.' in columns with numerical values
for column in world_data.columns:
    if (column != 'Country') and (world_data[column].dtype == 'object'):
        world_data[column] = world_data[column].str.replace(',', '.')
        world_data[column] = world_data[column].replace('NaN', np.NaN)
        world_data[column] = pd.to_numeric(world_data[column])

# %%
world_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 227 entries, ASIA (EX. NEAR EAST) to SUB-SAHARAN AFRICA
# Data columns (total 19 columns):
# Country                               227 non-null object
# Population                            227 non-null int64
# Area (sq. mi.)                        227 non-null int64
# Pop. Density (per sq. mi.)            227 non-null float64
# Coastline (coast/area ratio)          227 non-null float64
# Net migration                         224 non-null float64
# Infant mortality (per 1000 births)    224 non-null float64
# GDP ($ per capita)                    226 non-null float64
# Literacy (%)                          209 non-null float64
# Phones (per 1000)                     223 non-null float64
# Arable (%)                            225 non-null float64
# Crops (%)                             225 non-null float64
# Other (%)                             225 non-null float64
# Climate                               205 non-null float64
# Birthrate                             224 non-null float64
# Deathrate                             223 non-null float64
# Agriculture                           212 non-null float64
# Industry                              211 non-null float64
# Service                               212 non-null float64
# dtypes: float64(16), int64(2), object(1)
# memory usage: 35.5+ KB

# %%
# Get the EDA values for only complete data
complete_data = world_data.dropna()
complete_data.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  1.790000e+02    1.790000e+02                  179.000000
# mean   3.421415e+07    5.641830e+05                  294.805028
# std    1.317639e+08    1.395657e+06                 1379.352557
# min    1.347700e+04    2.800000e+01                    1.800000
# 25%    1.188580e+06    1.991500e+04                   26.800000
# 50%    6.940432e+06    1.184800e+05                   66.900000
# 75%    2.086014e+07    4.964410e+05                  164.700000
# max    1.313974e+09    9.631420e+06                16183.000000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    179.000000     179.000000
# mean                      16.495196      -0.206536
# std                       73.977601       4.751216
# min                        0.000000     -20.990000
# 25%                        0.090000      -1.315000
# 50%                        0.630000       0.000000
# 75%                        5.355000       0.395000
# max                      870.660000      23.060000
#
#        Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# count                          179.000000          179.000000    179.000000
# mean                            38.898156         9125.698324     81.944134
# std                             35.353003         9644.123141     19.837537
# min                              2.290000          500.000000     17.600000
# 25%                              9.990000         1800.000000     69.950000
# 50%                             24.310000         5100.000000     90.900000
# 75%                             64.605000        12950.000000     97.800000
# max                            163.070000        37800.000000    100.000000
#
#        Phones (per 1000)  Arable (%)   Crops (%)   Other (%)     Climate  \
# count         179.000000  179.000000  179.000000  179.000000  179.000000
# mean          208.151955   14.000447    4.440838   81.558212    2.108939
# std           210.121875   13.152405    8.090331   16.103748    0.697611
# min             0.200000    0.000000    0.000000   33.330000    1.000000
# 25%            27.100000    3.675000    0.230000   72.825000    2.000000
# 50%           137.100000   10.530000    1.030000   86.070000    2.000000
# 75%           335.000000   20.000000    4.600000   94.810000    2.500000
# max           898.000000   62.110000   48.960000  100.000000    4.000000
#
#         Birthrate   Deathrate  Agriculture    Industry     Service
# count  179.000000  179.000000   179.000000  179.000000  179.000000
# mean    23.067486    9.465140     0.156905    0.288028    0.554508
# std     11.287207    5.210083     0.151343    0.140310    0.165670
# min      7.290000    2.410000     0.000000    0.032000    0.062000
# 25%     13.890000    5.795000     0.039000    0.197000    0.424500
# 50%     20.460000    7.840000     0.101000    0.274000    0.559000
# 75%     32.315000   11.660000     0.233000    0.349000    0.668500
# max     50.730000   29.740000     0.769000    0.906000    0.954000

# %% [markdown]
# ## Visualizing Data
#
# Now we will try to chart some of the attributes and see how these change over different parts of the world.

# %%
# Get the number of countires in different regions of the world
countries_per_region = pd.DataFrame(world_data.groupby(level=[0])['Country'].count())
countries_per_region = countries_per_region.reset_index()

# Plot Number of countries in different regions of the world
plt.figure(figsize = (15,6))
ax = sns.barplot(x='Region', y='Country', data=countries_per_region)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_ylabel('Number of Countries');      # ; to suppress the output for this line

# %% [markdown]
# So from the above graph, we can see that most number of countries lie in Sub-Saharan Africa followed by Latin America and Caribbean. Baltics region has the least number of countries.

# %%
# Get locations for different countries from geopandas library
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
world.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 6 columns):
# pop_est       177 non-null float64
# continent     177 non-null object
# name          177 non-null object
# iso_a3        177 non-null object
# gdp_md_est    177 non-null float64
# geometry      177 non-null object
# dtypes: float64(2), object(4)
# memory usage: 8.4+ KB

# %%
# Test to check for a country
world_data[world_data['Country'] == 'Russia']
# Out:
#                     Country  Population  Area (sq. mi.)  \
# Region
# C.W. OF IND. STATES  Russia   142893540        17075200
#
#                      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# Region
# C.W. OF IND. STATES                         8.4                          0.22
#
#                      Net migration  Infant mortality (per 1000 births)  \
# Region
# C.W. OF IND. STATES           1.02                               15.39
#
#                      GDP ($ per capita)  Literacy (%)  Phones (per 1000)  \
# Region
# C.W. OF IND. STATES              8900.0          99.6              280.6
#
#                      Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# Region
# C.W. OF IND. STATES        7.33       0.11      92.56      NaN       9.95
#
#                      Deathrate  Agriculture  Industry  Service
# Region
# C.W. OF IND. STATES      14.65        0.054     0.371    0.575

# %%
# Plot world map using geopandas
world = world.rename(columns={'name':'Country', 'geometry':'borders'}).set_geometry('borders');
ax = world.plot(figsize=(18,16));

# %%
merged_data = world.merge(world_data, how='inner',on='Country').set_geometry('borders');
merged_data.head(5)
# Out:
#       pop_est      continent               Country iso_a3  gdp_md_est  \
# 0  28400000.0           Asia           Afghanistan    AFG     22270.0
# 1  12799293.0         Africa                Angola    AGO    110300.0
# 2   3639453.0         Europe               Albania    ALB     21810.0
# 3   4798491.0           Asia  United Arab Emirates    ARE    184300.0
# 4  40913584.0  South America             Argentina    ARG    573900.0
#
#                                              borders  Population  \
# 0  POLYGON ((61.21081709172574 35.65007233330923,...    31056997
# 1  (POLYGON ((16.32652835456705 -5.87747039146621...    12127071
# 2  POLYGON ((20.59024743010491 41.85540416113361,...     3581655
# 3  POLYGON ((51.57951867046327 24.24549713795111,...     2602713
# 4  (POLYGON ((-65.50000000000003 -55.199999999999...    39921833
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1         1246700                         9.7                          0.13
# 2           28748                       124.6                          1.26
# 3           82880                        31.4                          1.59
# 4         2766890                        14.4                          0.18
#
#     ...     Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 0   ...                   3.2       12.13       0.22      87.65      1.0
# 1   ...                   7.8        2.41       0.24      97.35      NaN
# 2   ...                  71.2       21.09       4.42      74.49      3.0
# 3   ...                 475.3        0.60       2.25      97.15      1.0
# 4   ...                 220.4       12.31       0.48      87.21      3.0
#
#    Birthrate  Deathrate  Agriculture  Industry  Service
# 0      46.60      20.34        0.380     0.240    0.380
# 1      45.11      24.20        0.096     0.658    0.246
# 2      15.11       5.22        0.232     0.188    0.579
# 3      18.96       4.40        0.040     0.585    0.375
# 4      16.73       7.55        0.095     0.358    0.547
#
# [5 rows x 24 columns]

# %%
merged_data.shape
# Out:
# (151, 24)

# %% [markdown]
# **NOTE:** It is important to note here that geopandas has data for about `177` countries while our original dataset had about `227` countries. And on taking an intersection, the combined dataset reduced even further, to `151` countries. For analysis purpose, the number of countries is not enough but for plotting purposes, it is fine. We do see some empty spaces on world maps, but still get a overall idea.

# %%
num_total_countries = 227
num_geopandas_countries = 177
num_intersection_countries = 151

# %%
perc_data_geopandas = (num_geopandas_countries / num_total_countries) * 100
perc_data_avail = (num_intersection_countries / num_total_countries) * 100

print("% of data in geopandas: ", perc_data_geopandas)
print("% of data available after intersection of geopandas with given dataset: ", perc_data_avail)
# Out:
# % of data in geopandas:  77.97356828193833
# % of data available after intersection of geopandas with given dataset:  66.51982378854625

# %% [markdown]
# So, in reality we are loosing about 35% of our original dataset when we are plotting on the worl map using geopandas. But to my knowledge, most of the data that is lost is for the countries which are much smaller. Data is still being plotted for the majority of big and relevant countries.

# %% [markdown]
# ### Population
#
# Population in this dataset refers to the total number of people in a country.

# %%
# Plot world population
merged_data.plot(column='Population', cmap='OrRd', figsize=(16,16))

# %%
reset_world_data = world_data.reset_index()
plt.figure(figsize = (15,6))
ax = sns.barplot(x='Region', y='Population', data=reset_world_data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %% [markdown]
# Above graph shows that most of the world population lies in the Asian region. This is indeed true because most of the population is in India and China (shown in next graph). Next region with highest population is the Northern America.

# %%
reset_world_data = reset_world_data.sort_values(by='Population', ascending=False)

plt.figure(figsize = (15,6))
ax = sns.barplot(x='Country', y='Population', data=reset_world_data[:10])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %% [markdown]
# Above graph shows that China and India are more than 3 times more populated than United States which ranks 3rd. The data on the graph is a little different from the latest data as given at: https://www.prb.org/wp-content/uploads/2018/08/2018_WPDS.pdf. In the latest data, Nigeria has more population than Bangladesh and Russia. Also, Mexico has come in the top 10 populated countries.

# %% [markdown]
# ### Birthrate
#
# In the given dataset, birthrate is the number of live births per thousand of population per year.

# %%
# Get a dataframe with entries that have non null birthrate values
birthrate_df = merged_data.loc[merged_data['Birthrate'].notnull(), :]
birthrate_df.sample(5)

ax = birthrate_df.plot(column='Birthrate', cmap='OrRd', figsize=(16,16))

# %% [markdown]
# Wait, India and China despite being the world's most populated don't have the highest birthrate? Atleast that's wat the data is saying. It is is showing that the birthrate is highest in most countries in the Sub-Saharan Africa(really dark colors) while somewhat high in most South-American and Asian Countries.

# %%
reset_world_data = world_data.reset_index()
plt.figure(figsize = (15,6))
ax = sns.boxplot(x='Region', y='Birthrate', data=reset_world_data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %% [markdown]
# From the above graph, we can clearly see that the range of birthrate is highest in Sub-Saharan Africa. Asia despite being the most populated, doesn't have the highest birthrate (however the highest birthrate in Asia is still comptetitive). This observation may come as a surprise.

# %%
reset_world_data = reset_world_data.sort_values(by='Birthrate', ascending=False)

plt.figure(figsize = (15,6))
ax = sns.barplot(x='Country', y='Birthrate', data=reset_world_data[:10])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %%
reset_world_data[(reset_world_data['Country'] == 'China') | (reset_world_data['Country'] == 'India')][['Country','Birthrate']]
# Out:
#    Country  Birthrate
# 94   India      22.01
# 42   China      13.25

# %% [markdown]
# So, `Nigeria` has the highest birthrate with value about 50, followed by `Mali` and `Uganda`. `India` and `China`, which have the highest population have less than half the birthrate than a lot of countries in `Africa`. What could be a reason for this? Maybe some sort of population control policies implemented by the governments in India and China can be the reason for lower birthrates and indeed that was the case for China.

# %% [markdown]
# ## Finding relationship between different Attributes

# %%
# Calcualtion relations between different attributes
corr_matrix = world_data.corr()
corr_matrix
# Out:
#                                     Population  Area (sq. mi.)  \
# Population                            1.000000        0.469985
# Area (sq. mi.)                        0.469985        1.000000
# Pop. Density (per sq. mi.)           -0.028190       -0.066917
# Coastline (coast/area ratio)         -0.068199       -0.095627
# Net migration                         0.000011        0.047470
# Infant mortality (per 1000 births)    0.023003       -0.007163
# GDP ($ per capita)                   -0.039324        0.072185
# Literacy (%)                         -0.043481        0.035994
# Phones (per 1000)                    -0.030819        0.053403
# Arable (%)                            0.188251       -0.079714
# Crops (%)                            -0.060757       -0.143916
# Other (%)                            -0.120606        0.138974
# Climate                              -0.026546       -0.117134
# Birthrate                            -0.045090       -0.066423
# Deathrate                            -0.028367        0.040079
# Agriculture                           0.000376       -0.050640
# Industry                              0.099333        0.121565
# Service                              -0.080852       -0.054369
#
#                                     Pop. Density (per sq. mi.)  \
# Population                                           -0.028190
# Area (sq. mi.)                                       -0.066917
# Pop. Density (per sq. mi.)                            1.000000
# Coastline (coast/area ratio)                          0.241690
# Net migration                                         0.178038
# Infant mortality (per 1000 births)                   -0.144238
# GDP ($ per capita)                                    0.195773
# Literacy (%)                                          0.097230
# Phones (per 1000)                                     0.280172
# Arable (%)                                           -0.081015
# Crops (%)                                            -0.031661
# Other (%)                                             0.081859
# Climate                                               0.009064
# Birthrate                                            -0.159192
# Deathrate                                            -0.070045
# Agriculture                                          -0.107142
# Industry                                             -0.139803
# Service                                               0.248774
#
#                                     Coastline (coast/area ratio)  \
# Population                                             -0.068199
# Area (sq. mi.)                                         -0.095627
# Pop. Density (per sq. mi.)                              0.241690
# Coastline (coast/area ratio)                            1.000000
# Net migration                                          -0.134145
# Infant mortality (per 1000 births)                     -0.136577
# GDP ($ per capita)                                      0.049118
# Literacy (%)                                            0.117095
# Phones (per 1000)                                       0.152129
# Arable (%)                                             -0.120772
# Crops (%)                                               0.341820
# Other (%)                                              -0.079494
# Climate                                                -0.032579
# Birthrate                                              -0.075765
# Deathrate                                              -0.161866
# Agriculture                                            -0.030250
# Industry                                               -0.199995
# Service                                                 0.196528
#
#                                     Net migration  \
# Population                               0.000011
# Area (sq. mi.)                           0.047470
# Pop. Density (per sq. mi.)               0.178038
# Coastline (coast/area ratio)            -0.134145
# Net migration                            1.000000
# Infant mortality (per 1000 births)      -0.025015
# GDP ($ per capita)                       0.382461
# Literacy (%)                            -0.008761
# Phones (per 1000)                        0.239601
# Arable (%)                              -0.058170
# Crops (%)                               -0.347968
# Other (%)                                0.225299
# Climate                                 -0.015170
# Birthrate                               -0.066537
# Deathrate                                0.033611
# Agriculture                             -0.116719
# Industry                                -0.026324
# Service                                  0.127134
#
#                                     Infant mortality (per 1000 births)  \
# Population                                                    0.023003
# Area (sq. mi.)                                               -0.007163
# Pop. Density (per sq. mi.)                                   -0.144238
# Coastline (coast/area ratio)                                 -0.136577
# Net migration                                                -0.025015
# Infant mortality (per 1000 births)                            1.000000
# GDP ($ per capita)                                           -0.600774
# Literacy (%)                                                 -0.765536
# Phones (per 1000)                                            -0.672312
# Arable (%)                                                   -0.113859
# Crops (%)                                                    -0.062366
# Other (%)                                                     0.124100
# Climate                                                      -0.374406
# Birthrate                                                     0.845764
# Deathrate                                                     0.656338
# Agriculture                                                   0.709475
# Industry                                                      0.003322
# Service                                                      -0.633982
#
#                                     GDP ($ per capita)  Literacy (%)  \
# Population                                   -0.039324     -0.043481
# Area (sq. mi.)                                0.072185      0.035994
# Pop. Density (per sq. mi.)                    0.195773      0.097230
# Coastline (coast/area ratio)                  0.049118      0.117095
# Net migration                                 0.382461     -0.008761
# Infant mortality (per 1000 births)           -0.600774     -0.765536
# GDP ($ per capita)                            1.000000      0.513144
# Literacy (%)                                  0.513144      1.000000
# Phones (per 1000)                             0.834499      0.601935
# Arable (%)                                    0.019768      0.105021
# Crops (%)                                    -0.219229      0.042825
# Other (%)                                     0.097828     -0.107563
# Climate                                       0.340791      0.392081
# Birthrate                                    -0.650137     -0.790846
# Deathrate                                    -0.201661     -0.393946
# Agriculture                                  -0.586769     -0.609638
# Industry                                     -0.028926      0.064733
# Service                                       0.550216      0.494607
#
#                                     Phones (per 1000)  Arable (%)  Crops (%)  \
# Population                                  -0.030819    0.188251  -0.060757
# Area (sq. mi.)                               0.053403   -0.079714  -0.143916
# Pop. Density (per sq. mi.)                   0.280172   -0.081015  -0.031661
# Coastline (coast/area ratio)                 0.152129   -0.120772   0.341820
# Net migration                                0.239601   -0.058170  -0.347968
# Infant mortality (per 1000 births)          -0.672312   -0.113859  -0.062366
# GDP ($ per capita)                           0.834499    0.019768  -0.219229
# Literacy (%)                                 0.601935    0.105021   0.042825
# Phones (per 1000)                            1.000000    0.061022  -0.152420
# Arable (%)                                   0.061022    1.000000   0.094361
# Crops (%)                                   -0.152420    0.094361   1.000000
# Other (%)                                    0.029900   -0.856763  -0.594254
# Climate                                      0.402161    0.380031   0.004343
# Birthrate                                   -0.724614   -0.186823   0.120687
# Deathrate                                   -0.260309    0.053472  -0.204961
# Agriculture                                 -0.601739   -0.034822   0.052941
# Industry                                    -0.152452   -0.063618  -0.117715
# Service                                      0.683934    0.091126   0.053946
#
#                                     Other (%)   Climate  Birthrate  Deathrate  \
# Population                          -0.120606 -0.026546  -0.045090  -0.028367
# Area (sq. mi.)                       0.138974 -0.117134  -0.066423   0.040079
# Pop. Density (per sq. mi.)           0.081859  0.009064  -0.159192  -0.070045
# Coastline (coast/area ratio)        -0.079494 -0.032579  -0.075765  -0.161866
# Net migration                        0.225299 -0.015170  -0.066537   0.033611
# Infant mortality (per 1000 births)   0.124100 -0.374406   0.845764   0.656338
# GDP ($ per capita)                   0.097828  0.340791  -0.650137  -0.201661
# Literacy (%)                        -0.107563  0.392081  -0.790846  -0.393946
# Phones (per 1000)                    0.029900  0.402161  -0.724614  -0.260309
# Arable (%)                          -0.856763  0.380031  -0.186823   0.053472
# Crops (%)                           -0.594254  0.004343   0.120687  -0.204961
# Other (%)                            1.000000 -0.305629   0.088586   0.062145
# Climate                             -0.305629  1.000000  -0.455097   0.011131
# Birthrate                            0.088586 -0.455097   1.000000   0.395302
# Deathrate                            0.062145  0.011131   0.395302   1.000000
# Agriculture                          0.001078 -0.210642   0.678207   0.382528
# Industry                             0.112091 -0.094945  -0.056953   0.026864
# Service                             -0.101518  0.272518  -0.557694  -0.359717
#
#                                     Agriculture  Industry   Service
# Population                             0.000376  0.099333 -0.080852
# Area (sq. mi.)                        -0.050640  0.121565 -0.054369
# Pop. Density (per sq. mi.)            -0.107142 -0.139803  0.248774
# Coastline (coast/area ratio)          -0.030250 -0.199995  0.196528
# Net migration                         -0.116719 -0.026324  0.127134
# Infant mortality (per 1000 births)     0.709475  0.003322 -0.633982
# GDP ($ per capita)                    -0.586769 -0.028926  0.550216
# Literacy (%)                          -0.609638  0.064733  0.494607
# Phones (per 1000)                     -0.601739 -0.152452  0.683934
# Arable (%)                            -0.034822 -0.063618  0.091126
# Crops (%)                              0.052941 -0.117715  0.053946
# Other (%)                              0.001078  0.112091 -0.101518
# Climate                               -0.210642 -0.094945  0.272518
# Birthrate                              0.678207 -0.056953 -0.557694
# Deathrate                              0.382528  0.026864 -0.359717
# Agriculture                            1.000000 -0.322909 -0.617039
# Industry                              -0.322909  1.000000 -0.544594
# Service                               -0.617039 -0.544594  1.000000

# %%
plt.figure(figsize = (13,13))

# Reverse the color map to see positive relations as darker colors
cmap = sns.cm.rocket_r

# Plot the correlation heatmap
ax = sns.heatmap(data=corr_matrix, cmap=cmap, annot=True, cbar=True, square=True, fmt='.2f')

# %% [markdown]
# So we can see certain very dominant correlations here (either very dark colors or very light colors). Some of the are explained here:
#
# - **Population:**
#    - Positive correlation with Area
# - **GDP:**
#     - Positive Correlation with Literacy, Phones, Service
#     - Negative Correlation with Birthrate, Agriculture
# - **Literacy:**
#     - Positive Correlation with Phones, Service
#     - Negative Correlation with Birthrate, Agriculture
# - **Phones:**
#     - Positive Correlation with Service
#     - Negative Correlation with Agriculture
# - **Service:**
#     - Negative Correlation with Agriculture, Birthrate
#
# Let's remove the unnecessary attributes to get a much clearer heatmap.

# %%
plt.figure(figsize = (13,13))

# Reverse the color map to see positive relations as darker colors
cmap = sns.cm.rocket_r

columns_to_process = ['Population', 'Infant mortality (per 1000 births)','Area (sq. mi.)','GDP ($ per capita)', 
                      'Literacy (%)', 'Phones (per 1000)', 'Birthrate', 'Agriculture', 'Service']

new_corr_matrix = world_data[columns_to_process].corr()

# Plot the correlation heatmap
ax = sns.heatmap(data=new_corr_matrix, cmap=cmap, annot=True, cbar=True, fmt='.2f', square=True,)

# %% [markdown]
# Now, it is much easier to look at the relation between different attributes. In this notebook, I will be only working to show the correlation of Population and GDP with other attributes. In the next commit, I will be adding the analysis of other attributes as well.

# %% [markdown]
# ## Population
#
# Population is the total number of people living in a country. From the correlation heatmap, we see that there is a positive relation between population and area of a country. From intuition, it makes sense that a bigger country can have larger population. For example, it is very likely that USA will have more population than Colombia. There are exceptions to this of course, for example India has higher population than USA(which is bigger) but these cases are relative. However, we are trying to find a general trend in the data.

# %% [markdown]
# ### Correlation with Area

# %%
plt.figure(figsize = (15,6))
ax = sns.relplot(x='Area (sq. mi.)', y='Population', hue='Region',  size=4, aspect=2, data=reset_world_data)

# %%
sorted_area_world_data = reset_world_data.sort_values(by='Area (sq. mi.)', ascending=False)
sorted_area_world_data
# Out:
#                    Region                           Country  Population  \
# 169   C.W. OF IND. STATES                            Russia   142893540
# 36       NORTHERN AMERICA                            Canada    33098932
# 214      NORTHERN AMERICA                     United States   298444215
# 42   ASIA (EX. NEAR EAST)                             China  1313973713
# 27    LATIN AMER. & CARIB                            Brazil   188078227
# 11                OCEANIA                         Australia    20264082
# 94   ASIA (EX. NEAR EAST)                             India  1095351995
# 8     LATIN AMER. & CARIB                         Argentina    39921833
# 106   C.W. OF IND. STATES                        Kazakhstan    15233244
# 192    SUB-SAHARAN AFRICA                             Sudan    41236378
# 2         NORTHERN AFRICA                           Algeria    32930091
# 45     SUB-SAHARAN AFRICA                  Congo, Dem. Rep.    62660551
# 80       NORTHERN AMERICA                         Greenland       56361
# 135   LATIN AMER. & CARIB                            Mexico   107449525
# 179             NEAR EAST                      Saudi Arabia    27019731
# 95   ASIA (EX. NEAR EAST)                         Indonesia   245452739
# 118       NORTHERN AFRICA                             Libya     5900754
# 96   ASIA (EX. NEAR EAST)                              Iran    68688433
# 139  ASIA (EX. NEAR EAST)                          Mongolia     2832224
# 161   LATIN AMER. & CARIB                              Peru    28302603
# 40     SUB-SAHARAN AFRICA                              Chad     9944201
# 151    SUB-SAHARAN AFRICA                             Niger    12525094
# 5      SUB-SAHARAN AFRICA                            Angola    12127071
# 128    SUB-SAHARAN AFRICA                              Mali    11716829
# 189    SUB-SAHARAN AFRICA                      South Africa    44187637
# 43    LATIN AMER. & CARIB                          Colombia    43593035
# 65     SUB-SAHARAN AFRICA                          Ethiopia    74777981
# 24    LATIN AMER. & CARIB                           Bolivia     8989046
# 132    SUB-SAHARAN AFRICA                        Mauritania     3177388
# 60        NORTHERN AFRICA                             Egypt    78887007
# ..                    ...                               ...         ...
# 7     LATIN AMER. & CARIB                 Antigua & Barbuda       69108
# 17    LATIN AMER. & CARIB                          Barbados      279912
# 208   LATIN AMER. & CARIB                 Turks & Caicos Is       21152
# 171    SUB-SAHARAN AFRICA                      Saint Helena        7502
# 175   LATIN AMER. & CARIB  Saint Vincent and the Grenadines      117848
# 134    SUB-SAHARAN AFRICA                           Mayotte      201234
# 74              NEAR EAST                        Gaza Strip     1428757
# 81    LATIN AMER. & CARIB                           Grenada       89703
# 129        WESTERN EUROPE                             Malta      400214
# 127  ASIA (EX. NEAR EAST)                          Maldives      359008
# 221               OCEANIA                 Wallis and Futuna       16025
# 38    LATIN AMER. & CARIB                    Cayman Islands       45436
# 172   LATIN AMER. & CARIB               Saint Kitts & Nevis       39129
# 174      NORTHERN AMERICA              St Pierre & Miquelon        7026
# 47                OCEANIA                      Cook Islands       21388
# 3                 OCEANIA                    American Samoa       57794
# 10    LATIN AMER. & CARIB                             Aruba       71891
# 119        WESTERN EUROPE                     Liechtenstein       33987
# 28    LATIN AMER. & CARIB                British Virgin Is.       23098
# 104        WESTERN EUROPE                            Jersey       91084
# 140   LATIN AMER. & CARIB                        Montserrat        9439
# 6     LATIN AMER. & CARIB                          Anguilla       13477
# 85         WESTERN EUROPE                          Guernsey       65409
# 177        WESTERN EUROPE                        San Marino       29251
# 22       NORTHERN AMERICA                           Bermuda       65773
# 122  ASIA (EX. NEAR EAST)                             Macau      453125
# 209               OCEANIA                            Tuvalu       11810
# 144               OCEANIA                             Nauru       13287
# 78         WESTERN EUROPE                         Gibraltar       27928
# 138        WESTERN EUROPE                            Monaco       32543
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 169        17075200                         8.4                          0.22
# 36          9984670                         3.3                          2.02
# 214         9631420                        31.0                          0.21
# 42          9596960                       136.9                          0.15
# 27          8511965                        22.1                          0.09
# 11          7686850                         2.6                          0.34
# 94          3287590                       333.2                          0.21
# 8           2766890                        14.4                          0.18
# 106         2717300                         5.6                          0.00
# 192         2505810                        16.5                          0.03
# 2           2381740                        13.8                          0.04
# 45          2345410                        26.7                          0.00
# 80          2166086                         0.0                          2.04
# 135         1972550                        54.5                          0.47
# 179         1960582                        13.8                          0.13
# 95          1919440                       127.9                          2.85
# 118         1759540                         3.4                          0.10
# 96          1648000                        41.7                          0.15
# 139         1564116                         1.8                          0.00
# 161         1285220                        22.0                          0.19
# 40          1284000                         7.7                          0.00
# 151         1267000                         9.9                          0.00
# 5           1246700                         9.7                          0.13
# 128         1240000                         9.5                          0.00
# 189         1219912                        36.2                          0.23
# 43          1138910                        38.3                          0.28
# 65          1127127                        66.3                          0.00
# 24          1098580                         8.2                          0.00
# 132         1030700                         3.1                          0.07
# 60          1001450                        78.8                          0.24
# ..              ...                         ...                           ...
# 7               443                       156.0                         34.54
# 17              431                       649.5                         22.51
# 208             430                        49.2                         90.47
# 171             413                        18.2                         14.53
# 175             389                       303.0                         21.59
# 134             374                       538.1                         49.52
# 74              360                      3968.8                         11.11
# 81              344                       260.8                         35.17
# 2        1.0      17.14       4.61        0.101     0.600    0.298
# 45       2.0      43.69      13.27        0.550     0.110    0.340
# 80       1.0      15.93       7.84          NaN       NaN      NaN
# 135      1.5      20.69       4.74        0.038     0.259    0.702
# 179      1.0      29.34       2.58        0.033     0.613    0.354
# 95       2.0      20.34       6.25        0.134     0.458    0.408
# 118      NaN      26.49       3.48        0.076     0.499    0.425
# 96       1.0      17.00       5.55        0.116     0.424    0.460
# 139      1.0      21.59       6.95        0.206     0.214    0.580
# 161      1.5      20.48       6.23        0.080     0.270    0.650
# 40       2.0      45.73      16.38        0.335     0.259    0.406
# 151      1.0      50.73      20.91        0.390     0.170    0.440
# 5        NaN      45.11      24.20        0.096     0.658    0.246
# 128      2.0      49.82      16.89        0.450     0.170    0.380
# 189      1.0      18.20      22.00        0.025     0.303    0.671
# 43       2.0      20.48       5.58        0.125     0.342    0.533
# 65       2.0      37.98      14.86        0.475     0.099    0.426
# 24       1.5      23.30       7.53        0.128     0.352    0.520
# 132      1.0      40.99      12.16        0.250     0.290    0.460
# 60       1.0      22.94       5.23        0.149     0.357    0.493
# ..       ...        ...        ...          ...       ...      ...
# 7        2.0      16.93       5.37        0.038     0.220    0.743
# 17       2.0      12.71       8.67        0.060     0.160    0.780
# 208      2.0      21.84       4.21          NaN       NaN      NaN
# 171      NaN      12.13       6.53          NaN       NaN      NaN
# 175      2.0      16.18       5.98        0.100     0.260    0.640
# 134      2.0      40.95       7.70          NaN       NaN      NaN
# 74       3.0      39.45       3.80        0.030     0.283    0.687
# 81       2.0      22.08       6.88        0.054     0.180    0.766
# 129      NaN      10.22       8.10        0.030     0.230    0.740
# 127      2.0      34.81       7.06        0.200     0.180    0.620
# 221      2.0        NaN        NaN          NaN       NaN      NaN
# 38       2.0      12.74       4.89        0.014     0.032    0.954
# 172      2.0      18.02       8.33        0.035     0.258    0.707
# 174      NaN      13.52       6.83          NaN       NaN      NaN
# 47       2.0      21.00        NaN        0.151     0.096    0.753
# 3        2.0      22.46       3.27          NaN       NaN      NaN
# 10       2.0      11.03       6.68        0.004     0.333    0.663
# 119      4.0      10.21       7.18        0.060     0.390    0.550
# 28       2.0      14.89       4.42        0.018     0.062    0.920
# 104      3.0       9.30       9.28        0.050     0.020    0.930
# 140      2.0      17.59       7.10          NaN       NaN      NaN
# 6        2.0      14.17       5.34        0.040     0.180    0.780
# 85       3.0       8.81      10.01        0.030     0.100    0.870
# 177      NaN      10.02       8.17          NaN       NaN      NaN
# 22       2.0      11.40       7.74        0.010     0.100    0.890
# 122      2.0       8.48       4.47        0.001     0.072    0.927
# 209      2.0      22.18       7.11        0.166     0.272    0.562
# 144      2.0      24.76       6.70          NaN       NaN      NaN
# 78       NaN      10.74       9.31          NaN       NaN      NaN
# 138      NaN       9.19      12.91        0.170       NaN      NaN
#
# [227 rows x 20 columns]

# %%
countries_in_small_patch = sorted_area_world_data[7:]

plt.figure(figsize = (15,6));
sns.relplot(x='Area (sq. mi.)', y='Population', hue='Region', size=4, aspect=2, data=countries_in_small_patch);

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(reset_world_data["Area (sq. mi.)"], reset_world_data["Population"])
print("Linear Regression - world data, r-2 value: ", r_value**2)

slope, intercept, r_value, p_value, std_err = stats.linregress(countries_in_small_patch["Area (sq. mi.)"], countries_in_small_patch["Population"])
print("Linear Regression - small patch, r-2 value: ", r_value**2)
# Out:
# Linear Regression - world data, r-2 value:  0.22088597891786851
# Linear Regression - small patch, r-2 value:  0.19902791203169246

# %%
plt.figure(figsize = (15,6))
ax = sns.regplot(x='Area (sq. mi.)', y='Population', data=reset_world_data, ci=50)

# %%
plt.figure(figsize = (15,6))
ax = sns.regplot(x='Area (sq. mi.)', y='Population', data=countries_in_small_patch)

# %% [markdown]
# So, from linear regression, only 22% is predictable which is not great and it decreases when we remove extremes. But if we keep that aside for a moment, what we can see is that our initial idea was right that the `population generally increases with area`.

# %% [markdown]
# ## GDP
#
# In the given data set, GDP is the total value of goods produced and services provided in a country per person during one year. One may expect that the GDP value will be higher in the developed countries and lower in developing countries. Let's try to look for the trend in GDP and its impact.

# %%
merged_data.plot(column='GDP ($ per capita)', figsize=(18,12), legend=True)

# %% [markdown]
# The world map shows the distribution of the GDP across the world. As you can see, USA has one the highest GDP in the world.

# %%
plt.figure(figsize=(10,6))
ax = sns.boxplot(x='Region', y='GDP ($ per capita)', data=reset_world_data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %%
sorted_gdp_world_data = reset_world_data.sort_values(by='GDP ($ per capita)', ascending=False)
sorted_gdp_world_data
# Out:
#                    Region               Country  Population  Area (sq. mi.)  \
# 121        WESTERN EUROPE            Luxembourg      474413            2586
# 214      NORTHERN AMERICA         United States   298444215         9631420
# 154        WESTERN EUROPE                Norway     4610820          323802
# 22       NORTHERN AMERICA               Bermuda       65773              53
# 38    LATIN AMER. & CARIB        Cayman Islands       45436             262
# 177        WESTERN EUROPE            San Marino       29251              61
# 196        WESTERN EUROPE           Switzerland     7523934           41290
# 54         WESTERN EUROPE               Denmark     5450661           43094
# 93         WESTERN EUROPE               Iceland      299388          103000
# 12         WESTERN EUROPE               Austria     8192880           83870
# 36       NORTHERN AMERICA                Canada    33098932         9984670
# 98         WESTERN EUROPE               Ireland     4062235           70280
# 19         WESTERN EUROPE               Belgium    10379067           30528
# 11                OCEANIA             Australia    20264082         7686850
# 91   ASIA (EX. NEAR EAST)             Hong Kong     6940432            1092
# 146        WESTERN EUROPE           Netherlands    16491461           41526
# 103  ASIA (EX. NEAR EAST)                 Japan   127463611          377835
# 10    LATIN AMER. & CARIB                 Aruba       71891             193
# 213        WESTERN EUROPE        United Kingdom    60609153          244820
# 69         WESTERN EUROPE                France    60876136          547030
# 76         WESTERN EUROPE               Germany    82422299          357021
# 68         WESTERN EUROPE               Finland     5231372          338145
# 138        WESTERN EUROPE                Monaco       32543               2
# 195        WESTERN EUROPE                Sweden     9016596          449964
# 101        WESTERN EUROPE                 Italy    58133509          301230
# 119        WESTERN EUROPE         Liechtenstein       33987             160
# 104        WESTERN EUROPE                Jersey       91084             116
# 58        6.24        0.085     0.231    0.684
# 223        NaN          NaN       NaN    0.400
#
# [227 rows x 20 columns]

# %% [markdown]
# On a general trend, Northern America and Western Europe have the highest GDP in the world. It is not hard to relate that to real life since most of the developed or first world countries lie in these regions. `Luxembourg` has the highest GDP with a value of 551000 $ per capita.

# %% [markdown]
# ### Correlation with Literacy

# %%
ax = sns.relplot(x='GDP ($ per capita)', y='Literacy (%)', data=reset_world_data, kind='line', size=4, aspect=2, ci=0, legend=False)

# %%
plt.figure(figsize=(12,6))
ax = sns.regplot(x='GDP ($ per capita)', y='Literacy (%)', data=reset_world_data, order=1, robust=True, ci=None)

# %% [markdown]
# Hence, as the GDP($ per capita) increases, so does the literacy rate. One of the reasons that I can come up with is that people with higher GDP can spend more on education. Countries with lower GDP will find it hard to apy the costs that are associated with education whether it be salaries of teachers or the school supplies.

# %% [markdown]
# ### Correlation with Phones

# %%
data_without_nans = reset_world_data[['GDP ($ per capita)','Phones (per 1000)']].dropna()
ax = sns.relplot(x='GDP ($ per capita)', y='Phones (per 1000)', data=data_without_nans, kind='line', size=4, aspect=2, ci=0, legend=False)

# %%
plt.figure(figsize=(12,6))
ax = sns.regplot(x='GDP ($ per capita)', y='Phones (per 1000)', data=data_without_nans, order=1, ci=None, robust=True)

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(data_without_nans['GDP ($ per capita)'], data_without_nans['Phones (per 1000)'])
print("Linear Regression - world data, slope: ", slope)
print("Linear Regression - world data, r-2 value: ", r_value**2)
# Out:
# Linear Regression - world data, slope:  0.018895677085984885
# Linear Regression - world data, r-2 value:  0.6963890406665653

# %% [markdown]
# We can see that there is a positive relation, a slope of 0.02 and the linear regression line fits the data very well, r-squared value of about 0.7.
# So, it means as the GDP increases, the number of phones in a country increases. This is very intuitive finding, people will buy a mobile phone only if they can afford it. But there is a strange observation in line graph. We see that the increasing trend continues till GDP of about $35000 and then it falls. So, Luxembourg has the highest GDP but less number of phones per 1000 people. What could be the reason for it?
# According to Deloitte (https://www2.deloitte.com/lu/en/pages/technology-media-and-telecommunications/articles/global-mobile-consumer-survey-2017-press-release.html), most of the people in Luxembourg don't use their cellphones for calling but for messaging and writing emails. I would assume that most of the phone usage is for professional purposes. Hence, majority of non-adult population don't use phones. I would like to tell that this is just a speculation, what I try to guess from data. Validation needs to be done from actual situation and research.

# %% [markdown]
# ### Correlation with Birthrate

# %%
data_without_nans = reset_world_data[['GDP ($ per capita)','Birthrate', 'Infant mortality (per 1000 births)']].dropna()

plt.figure(figsize=(16,6))
ax = sns.lineplot(x='GDP ($ per capita)', y='Birthrate', data=data_without_nans, ci=0, legend=False)

# %%
plt.figure(figsize=(12,6))
ax = sns.regplot(x='GDP ($ per capita)', y='Birthrate', data=data_without_nans, order=1, ci=None, robust=True)

# %% [markdown]
# Both the graphs reflect a downward trend of Birthrate as GDP decreases. This is a well known trend. According to Federal Reserve Bank of St. Louis(https://www.stlouisfed.org/on-the-economy/2016/december/link-fertility-income), there are several possible reasons for higher birthrate in countries with low GDP:
#
# - Time is relatively cheap in poor countries, so spending time away from work to take care of a child is not as costly as in a rich country. If this effect is strong enough, it can (and probably does) offset the fact that it is difficult to afford a child on a low income.
# - A child may require more education to be successful in a rich country. Thus, a child may be more costly there, so families may opt to have fewer, more educated children.
# - Infant mortality can play a role. More births might be needed to achieve a desired number of surviving children when infant mortality is high, as it tends to be in poor countries (shown below).

# %%
# Plot Birthrate and infant Mortality together against GDP
plt.figure(figsize=(14,6))

# add birthrate on primary y-axis
ax = sns.lineplot(x='GDP ($ per capita)', y='Birthrate', data=data_without_nans, ci=0, label='Birthrate')
ax.legend(loc='center right', bbox_to_anchor=(0.7, 0.95))

# add Infant mortality on secondary y-axis
ax2 = ax.twinx()
sns.lineplot(ax=ax2, x='GDP ($ per capita)', y='Infant mortality (per 1000 births)',color='green',data=data_without_nans, ci=0, legend=False)
ax2.lines[0].set_linestyle("--")

# Change the plot settings for easy viewing
ax.yaxis.grid(which="major", linewidth=1)
ax2.yaxis.grid(which="major",linewidth=0.5, linestyle='--')
ax2.set_yticks(np.linspace(ax2.get_yticks()[0], ax2.get_yticks()[-1], len(ax.get_yticks())));

# %% [markdown]
# ### Correlation with Service and Agriculture

# %%
data_without_nans = reset_world_data[['GDP ($ per capita)','Service', 'Industry', 'Agriculture']].dropna()
data_without_nans.sample(5)
# Out:
#      GDP ($ per capita)  Service  Industry  Agriculture
# 169              8900.0    0.575     0.371        0.054
# 129             17700.0    0.740     0.230        0.030
# 193              4000.0    0.650     0.220        0.130
# 11              29000.0    0.700     0.262        0.038
# 190             22000.0    0.665     0.295        0.040

# %%
plt.figure(figsize=(13,6))

# Plot the Service values
ax = sns.lineplot(x='GDP ($ per capita)', y='Service', data=data_without_nans, ci=0, label="Service")

# plot the Agriculture values
ax2 = ax.twinx()
sns.lineplot(ax=ax2, x='GDP ($ per capita)', y='Agriculture', color="g", data=data_without_nans, ci=0, label="Agriculture")
sns.lineplot(ax=ax2, x='GDP ($ per capita)', y='Industry', color="r", data=data_without_nans, ci=0, label="Industry")

# Set legend
ax2.legend(loc='center right')
ax.legend(loc='center right', bbox_to_anchor=(1, 0.6))

# Set plot settings for easy viewing
ax.yaxis.grid(which="major", linewidth=1)
ax2.yaxis.grid(which="major",linewidth=0.5, linestyle='--')
ax2.set_yticks(np.linspace(0, ax2.get_yticks()[-1], len(ax.get_yticks())));

# %%
plt.figure(figsize=(12,6));
sns.regplot(x='GDP ($ per capita)', y='Service', data=data_without_nans, order=1, ci=None, robust=True);

# %%
plt.figure(figsize=(12,6));
sns.regplot(x='GDP ($ per capita)', y='Industry', data=data_without_nans, order=1, ci=None, robust=True);

# %%
plt.figure(figsize=(12,6));
sns.regplot(x='GDP ($ per capita)', y='Agriculture', data=data_without_nans, ci=None, truncate=True);

# %% [markdown]
# From the above graphs, we can conclude that GDP increases when the majority of conutry's economy depends on Service sector and not agriculture. A good example of this is shown below form the given data:
#
# - Liberia and Somalia have high percentage of their economy depended on agriculture. The GDP for botht he countries is lower or equal than $1000. This is quiet low.
#
# - On the other hand, Jersey and Cayman Islands have high percentage of their economy depended on service sector. The resultant GDP in these countries are about $25,000 or higher. These values may not be the highest, but they are comparatively very high.
#
# Also, it seems industry sector does not play a significant role in GDP. Rather it has a slight downward slop, indicating inverse relation, but we can also see that the data doesn't exactly fit the linear regression well.

# %%
col_to_print = ['Region','Country', 'GDP ($ per capita)', 'Agriculture', 'Industry', 'Service']

# %%
print("Countries with highest Service:")
reset_world_data.sort_values('Service', ascending=False)[col_to_print].head(5)
# Out:
# Countries with highest Service:
#                    Region             Country  GDP ($ per capita)  \
# 38    LATIN AMER. & CARIB      Cayman Islands             35000.0
# 104        WESTERN EUROPE              Jersey             24800.0
# 122  ASIA (EX. NEAR EAST)               Macau             19400.0
# 28    LATIN AMER. & CARIB  British Virgin Is.             16000.0
# 91   ASIA (EX. NEAR EAST)           Hong Kong             28800.0
#
#      Agriculture  Industry  Service
# 38         0.014     0.032    0.954
# 104        0.050     0.020    0.930
# 122        0.001     0.072    0.927
# 28         0.018     0.062    0.920
# 91         0.001     0.092    0.906

# %%
print("Countries with highest Industry:")
reset_world_data.sort_values('Industry', ascending=False)[col_to_print].head(5)
# Out:
# Countries with highest Industry:
#                  Region            Country  GDP ($ per capita)  Agriculture  \
# 62   SUB-SAHARAN AFRICA  Equatorial Guinea              2700.0        0.030
# 166           NEAR EAST              Qatar             21500.0        0.002
# 97            NEAR EAST               Iraq              1500.0        0.073
# 5    SUB-SAHARAN AFRICA             Angola              1900.0        0.096
# 179           NEAR EAST       Saudi Arabia             11800.0        0.033
#
#      Industry  Service
# 62      0.906    0.062
# 166     0.801    0.197
# 97      0.666    0.261
# 5       0.658    0.246
# 179     0.613    0.354

# %%
print("Countries with highest Agriculture:")
reset_world_data.sort_values('Agriculture', ascending=False)[col_to_print].head(5)
# Out:
# Countries with highest Agriculture:
#                    Region               Country  GDP ($ per capita)  \
# 117    SUB-SAHARAN AFRICA               Liberia              1000.0
# 188    SUB-SAHARAN AFRICA               Somalia               500.0
# 87     SUB-SAHARAN AFRICA         Guinea-Bissau               800.0
# 32   ASIA (EX. NEAR EAST)                 Burma              1800.0
# 39     SUB-SAHARAN AFRICA  Central African Rep.              1100.0
#
#      Agriculture  Industry  Service
# 117        0.769     0.054    0.177
# 188        0.650     0.100    0.250
# 87         0.620     0.120    0.260
# 32         0.564     0.082    0.353
# 39         0.550     0.200    0.250

# %% [markdown]
# From above tables, we can conclude that:
#
# - GDP is directly proportional to the contribution from Service sector and inverserly proportional to the contribution from Service sector.
# - From the table above with countries having highest Industry contribution, it is hard to find exact relation to GDP since the higher industry contribution lead to erratic GDP values. In some cases, the Industry contribution is high and the GDP as well (eg - Qatar), but there are cases where value is high but the GDP is low(eg -Equatorial Guinea).
# - A much more sensible measure to check would be to combine Industry and Service sectors and check them against Agriculture and then try to find their impact on GDP. I believe higher the value of the Service and Industry combination, higher will be the GDP. If the combined value is lower, then the GDP will drop. This can result in much more accureate measurements.
#
# Finding that the highest Service sector values do not yield the best GDP, then what is a good combination of Service, Agriculture and Industry contributions? What values could result in better GDP? What proportion of a country's economy should be in each sector for maximum development? I shall leave that for future work.
